# %% [markdown]
# # Analisi dello Spazio dei Parametri
# esplorariamo lo spazio dei parametri e le condizioni teoriche del modello

# %%
import sys
sys.path.append("/Users/sofiacattaneo/tesi-inequality/src")

print(sys.path)
# Out:
# ['/Users/sofiacattaneo/opt/anaconda3/envs/tesi/lib/python311.zip', '/Users/sofiacattaneo/opt/anaconda3/envs/tesi/lib/python3.11', '/Users/sofiacattaneo/opt/anaconda3/envs/tesi/lib/python3.11/lib-dynload', '', '/Users/sofiacattaneo/opt/anaconda3/envs/tesi/lib/python3.11/site-packages', '/Users/sofiacattaneo/tesi-inequality/src']

# %%
from parameters import *
from functions import *
from conditions import *
from distributions import uniform_initial
from simulations_det import simulate_det

# %%
history=simulate_det(lambda N: uniform_initial(N, low=0, high=0.7))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 history=simulate_det(lambda N: uniform_initial(N, low=0, high=0.7))
#       2
#
# TypeError: simulate_det() missing 2 required positional arguments: 'update_wealth' and 'T'

# %%
import matplotlib.pyplot as plt

plt.hist(history[0], bins=100)
plt.title("Distribuzione iniziale")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.hist(history[0], bins=100)
#       4 plt.title("Distribuzione iniziale")
#       5 plt.show()
#
# NameError: name 'history' is not defined
